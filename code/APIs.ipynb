# %%
import tweepy

# %%
# Go to http://apps.twitter.com and create an app.
# The consumer key and secret will be generated for you after
consumer_key='8l38rrT5sRZA2Xu2OnpKjVEjb'
consumer_secret='ZVHO4kE5Lg655peFC5ysEMf8WyEfouWJTvZtVDfC2HuliOWglN'


# After the step above, you will be redirected to your app's page.
# Create an access token under the the "Your access token" section
access_token='2390456413-Z0zYToRU7ceV06TJ40pyrpKzVX5CKb41DgLI9h1'
access_token_secret='yrLwPl9gweAcH35Dn93aS2tHYuXG3jowGnvmk7SlFghWH'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet)
    print('')
# Out:
# Status(_api=<tweepy.api.API object at 0x1047807f0>, _json={'created_at': 'Fri Apr 26 19:08:52 +0000 2019', 'id': 1121853670801457153, 'id_str': '1121853670801457153', 'text': 'Several members of the Evanston Police Department joined members of the Skokie Police Department at Walker School M… https://t.co/wCuHbzfaJ8', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/wCuHbzfaJ8', 'expanded_url': 'https://twitter.com/i/web/status/1121853670801457153', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1365471444, 'id_str': '1365471444', 'name': 'Evanston, IL Police', 'screen_name': 'EvanstonPD', 'location': 'Evanston, IL', 'descript
# ...

# %%
# print statuses of a user
user = api.get_user('redabahrani')

friends = api.friends('redabahrani')

for friend in friends:
    print(friend.name)
# Out:
# Serena Yeung
# Albert Berahas
# Nintendo Switch
# Francesca Cornelli
# AAAI
# بندر العليو
# الاتحاد السعودي للتسلق والهايكنج
# Badeya Alreda |  بديع الرضاء
# Sheera Frenkel
# ML Review
# The Stanford AI Lab
# SIAM Data Mining
# Claire Lew
# Ben Callahan
# Emily Harburg
# خدمة العملاء | البنك السعودي الفرنسي
# البنك السعودي الفرنسي
# SanDisk
# Engadget
# Chelsea Finn

# %%
following = api.friends_ids('redabahrani')
# api.
for f in following:
    test = api.get_user(f)
    print(test.name)
# Out:
# Serena Yeung
# Albert Berahas
# Nintendo Switch
# Francesca Cornelli
# AAAI
# بندر العليو
# الاتحاد السعودي للتسلق والهايكنج
# Badeya Alreda |  بديع الرضاء
# Sheera Frenkel
# ML Review
# The Stanford AI Lab
# SIAM Data Mining
# Claire Lew
# Ben Callahan
# Emily Harburg
# خدمة العملاء | البنك السعودي الفرنسي
# البنك السعودي الفرنسي
# SanDisk
# Engadget
# Chelsea Finn
# Adnan AlBahrani
# Yisong Yue
# icdm2019
# AbilityLab
# Lambda School
# Ian Goodfellow
# Fei-Fei Li
# Andrew Ng
# Hire.ai
# Haley Yaple
# Ali H. Alhasan علي
# Evanston, IL Police
# Northwestern
# PyTorch
# Margaret Danilovich
# ICML Conference
# Yann LeCun
# Google AI
# Jack Clark
# NeurIPS Conference
# Arindam Paul
# Mohammed Alam
# Rosanne Liu
# Dipendra Jha
# Andrej Karpathy
# The Garage
# 🔎Julia Evans🔍
# Haidar AlMubarak
# Hoosier Mama Pie Co
# MediaFire
# dj patil
# Northwestern Shuttles
# Roger D. Peng
# محمد الحاجي
# Hilary Parker
# DataTau
# Karthik Ram
# Lada Adamic
# Lavaca
# Usama Fayyad
# Sean J. Taylor
# ...

# %%
from __future__ import absolute_import, print_function
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

# %%
class StdOutListener(StreamListener):
    """ A listener handles tweets that are received from the stream.
    This is a basic listener that just prints received tweets to stdout.

    """
    def on_data(self, data):
        print(data)
        return True


    def on_error(self, status):
        print(status)


if __name__ == '__main__':
    l = StdOutListener()
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)


    stream = Stream(auth, l)
    stream.filter(track=['football'])
# Out:
# {"created_at":"Fri Apr 26 19:30:40 +0000 2019","id":1121859153696317443,"id_str":"1121859153696317443","text":"RT @NFL_DovKleiman: Such a weird way to say \"Everyone\" were pissed off a him... would've been a lot easier. \n\nAlso, who says \"the blacks\"?\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":361967583,"id_str":"361967583","name":"Court Targaryen","screen_name":"CourtneeHendrix","location":"Birmingraq","url":null,"description":"(@iamunique_23) Samford Alum","translator_type":"none","protected":false,"verified":false,"followers_count":3292,"friends_count":1759,"listed_count":198,"favourites_count":6643,"statuses_count":647658,"created_at":"Thu Aug 25 16:43:46 +0000 2011","utc_offset":null,"time_zone":null,"geo_enabl
# ...

# %%
import json
import requests

s = '{"data": [{"text": "the food was horrible."}, {"text": "I love the food."}, {"text": "the food is ok"}]}'
url = 'http://www.sentiment140.com/api/bulkClassifyJson?appid=redaalbahrani2012@u.northwestern.edu'
r = requests.post(url, data=s)
responses = json.loads(r.text)['data']
print(responses)
# Out:
# [{'meta': {'language': 'en'}, 'text': 'the food was horrible.', 'polarity': 0}, {'meta': {'language': 'en'}, 'text': 'I love the food.', 'polarity': 4}, {'meta': {'language': 'en'}, 'text': 'the food is ok', 'polarity': 2}]
